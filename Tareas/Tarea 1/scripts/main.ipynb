# %% [markdown]
# Importamos librerías y los datos del archivo csv

# %%
import bnlearn as bn

import pandas as pd


df = bn.import_example()

#dataframe
df = pd.read_csv('../dataset18.csv')
# Out:
# [bnlearn] >Import dataset..

# %%
graph = bn.structure_learning.fit(df)

G = bn.plot(graph)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model

# %% [markdown]
# Ahora se ajusta aun más con lo que mostró el ayudante y con esto podemos inferir

# %%
model_update = bn.parameter_learning.fit(graph, df) #ejecución de aprendizaje por parametros mediante el gráfo y dataframe

Gg = bn.plot(model_update, interactive=True, params_interactive={'notebook': True}) #Grafico red bayesiana
# Out:
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >Converting [<class 'pgmpy.base.DAG.DAG'>] to BayesianNetwork model.
# [bnlearn] >Converting adjmat to BayesianNetwork.
# [bnlearn] >CPD of inflacion:
# +---------------+---------------------+---------------------+
# | precios_altos | precios_altos(0)    | precios_altos(1)    |
# +---------------+---------------------+---------------------+
# | inflacion(0)  | 0.17312463335940556 | 0.06513988339092538 |
# +---------------+---------------------+---------------------+
# | inflacion(1)  | 0.8268753666405945  | 0.9348601166090746  |
# +---------------+---------------------+---------------------+
# [bnlearn] >CPD of guerra_ucrania:
# +-------------------+-----+--------------------+
# | inflacion         | ... | inflacion(1)       |
# +-------------------+-----+--------------------+
# | precios_altos     | ... | precios_altos(1)   |
# +-------------------+-----+--------------------+
# | guerra_ucrania(0) | ... | 0.1800977741224066 |
# +-------------------+-----+--------------------+
# | guerra_ucrania(1) | ... | 0.8199022258775934 |
# +-------------------+-----+--------------------+
# [bnlearn] >CPD of escasez:
# +----------------+-----+---------------------+
# | guerra_ucrania | ... | guerra_ucrania(1)   |
# +----------------+-----+---------------------+
# | precios_altos  | ... | precios_altos(1)    |
# +----------------+-----+---------------------+
# | escasez(0)     | ... | 0.20079186984055394 |
# +----------------+-----+---------------------+
# | escasez(1)     | ... | 0.799208130159446   |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of no_carne:
# +----------------+-----+--------------------+
# | guerra_ucrania | ... | guerra_ucrania(1)  |
# +----------------+-----+--------------------+
# | precios_altos  | ... | precios_altos(1)   |
# +----------------+-----+--------------------+
# | no_carne(0)    | ... | 0.1000502774501939 |
# +----------------+-----+--------------------+
# | no_carne(1)    | ... | 0.8999497225498061 |
# +----------------+-----+--------------------+
# [bnlearn] >CPD of no_confort:
# +----------------+-----+---------------------+
# | guerra_ucrania | ... | guerra_ucrania(1)   |
# +----------------+-----+---------------------+
# | precios_altos  | ... | precios_altos(1)    |
# +----------------+-----+---------------------+
# | no_confort(0)  | ... | 0.40004768964025744 |
# +----------------+-----+---------------------+
# | no_confort(1)  | ... | 0.5999523103597425  |
# +----------------+-----+---------------------+
# [bnlearn] >CPD of precios_altos:
# +------------------+----------+
# | precios_altos(0) | 0.326969 |
# +------------------+----------+
# | precios_altos(1) | 0.673031 |
# +------------------+----------+
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# <html>
# <head>
# <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/vis-network@latest/styles/vis-network.css" type="text/css" />
# <script type="text/javascript" src="https://cdn.jsdelivr.net/npm/vis-network@latest/dist/vis-network.min.js"> </script>
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#
# <style type="text/css">
#
#         #mynetwork {
#             width: 70%;
#             height: 800px;
#             background-color: #ffffff;
#             border: 1px solid lightgray;
#             position: relative;
#             float: left;
#         }
#
#
#
#
#         #config {
#             float: left;
#             width: 400px;
#             height: 600px;
#         }
#
#
#
# </style>
#
# </head>
#
# <body>
# <div id = "mynetwork"></div>
#
#
# <div id = "config"></div>
#
# <script type="text/javascript">
#
#     // initialize global variables.
#     var edges;
#     var nodes;
#     var network;
#     var container;
#     var options, data;
#
#
#     // This method is responsible for drawing the graph, returns the drawn network
#     function drawGraph() {
#         var container = document.getElementById('mynetwork');
#
#
#
#         // parsing and collecting nodes and edges from the python
#         nodes = new vis.DataSet([{"color": "#1f456e", "id": "inflacion", "label": "inflacion", "shape": "dot", "size": 10}, {"color": "#1f456e", "id": "guerra_ucrania", "label": "guerra_ucrania", "shape": "dot", "size": 10}, {"color": "#1f456e", "id": "escasez", "label": "escasez", "shape": "dot", "size": 10}, {"color": "#1f456e", "id": "no_carne", "label": "no_carne", "shape": "dot", "size": 10}, {"color": "#1f456e", "id": "no_confort", "label": "no_confort", "shape": "dot", "size": 10}, {"color": "#1f456e", "id": "precios_altos", "label": "precios_altos", "shape": "dot", "size": 10}]);
#         edges = new vis.DataSet([{"arrows": "to", "color": "#000000", "from": "inflacion", "label": 1.0, "to": "guerra_ucrania", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "guerra_ucrania", "label": 1.0, "to": "escasez", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "guerra_ucrania", "label": 1.0, "to": "no_carne", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "guerra_ucrania", "label": 1.0, "to": "no_confort", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "precios_altos", "label": 1.0, "to": "inflacion", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "precios_altos", "label": 1.0, "to": "guerra_ucrania", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "precios_altos", "label": 1.0, "to": "escasez", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "precios_altos", "label": 1.0, "to": "no_carne", "weight": 1}, {"arrows": "to", "color": "#000000", "from": "precios_altos", "label": 1.0, "to": "no_confort", "weight": 1}]);
#
#         // adding nodes and edges to the graph
#         data = {nodes: nodes, edges: edges};
#
#         var options = {
#     "configure": {
#         "enabled": true,
#         "filter": [
#             "physics"
#         ]
#     },
#     "edges": {
#         "color": {
#             "inherit": true
#         },
#         "smooth": {
#             "enabled": true,
#             "type": "dynamic"
#         }
#     },
#     "interaction": {
#         "dragNodes": true,
#         "hideEdgesOnDrag": false,
#         "hideNodesOnDrag": false
#     },
#     "physics": {
#         "enabled": true,
#         "stabilization": {
#             "enabled": true,
#             "fit": true,
#             "iterations": 1000,
#             "onlyDynamicEdges": false,
#             "updateInterval": 50
#         }
#     }
# };
#
#
#
#
#         // if this network requires displaying the configure window,
#         // put it in its div
#         options.configure["container"] = document.getElementById("config");
#
#
#         network = new vis.Network(container, data, options);
#
#
#
#
#
#
#         return network;
#
#     }
#
#     drawGraph();
#
# </script>
# </body>
# </html>
