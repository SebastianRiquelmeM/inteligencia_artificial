# %%
import bnlearn as bn

import pandas as pd

df = bn.import_example()

#dataframe
df = pd.read_csv('../dataset18.csv')
# Out:
# [bnlearn] >Import dataset..

# %%
model = bn.structure_learning.fit(df, methodtype='hc', scoretype='bic')

model = bn.plot(model)

print( model )
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Set node properties.
# [bnlearn] >Set edge properties.
# [bnlearn] >Plot based on Bayesian model
# {'pos': {'inflacion': array([-0.11770318, -0.05674102]), 'guerra_ucrania': array([-0.18659521,  0.0931098 ]), 'precios_altos': array([-0.14944692,  0.07663827]), 'escasez': array([-0.3145533 , -0.73362664]), 'no_carne': array([0.27609384, 0.6530176 ]), 'no_confort': array([-0.50779524,  0.55234471]), 'no_alcohol': array([ 1.        , -0.58474272])}, 'G': <networkx.classes.digraph.DiGraph object at 0x7fe08e2e3ca0>, 'node_properties': {'inflacion': {'node_color': '#1f456e', 'node_size': 800}, 'guerra_ucrania': {'node_color': '#1f456e', 'node_size': 800}, 'precios_altos': {'node_color': '#1f456e', 'node_size': 800}, 'escasez': {'node_color': '#1f456e', 'node_size': 800}, 'no_carne': {'node_color': '#1f456e', 'node_size': 800}, 'no_confort': {'node_color': '#1f456e', 'node_size': 800}, 'no_alcohol': {'node_color': '#1f456e', 'node_size': 800}}, 'edge_properties': {('inflacion', 'guerra_ucrania'): {'color': '#000000', 'weight': 1}, ('guerra_ucrania', 'escasez'): {'color': '#000000', 'weight': 1}, ('guerra_ucrania', 'no_carne'): {'color': '#000000', 'weight': 1}, ('guerra_ucrania', 'no_confort'): {'color': '#000000', 'weight': 1}, ('precios_altos', 'inflacion'): {'color': '#000000', 'weight': 1}, ('precios_altos', 'guerra_ucrania'): {'color': '#000000', 'weight': 1}, ('precios_altos', 'escasez'): {'color': '#000000', 'weight': 1}, ('precios_altos', 'no_carne'): {'color': '#000000', 'weight': 1}, ('precios_altos', 'no_confort'): {'color': '#000000', 'weight': 1}}}
